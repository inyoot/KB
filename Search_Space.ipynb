# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-2, 2, 0.01)
Y = np.arange(-1, 3, 0.01)
X, Y = np.meshgrid(X, Y)
#https://en.wikipedia.org/wiki/Rosenbrock_function
Z = (1-X)**2 + 1 *(Y-X**2)**2
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.gist_stern,
                       linewidth=0, antialiased=False)

# Customize the z axis.
#ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


# Plot a basic wireframe.
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

plt.show()

# %%
levels = np.linspace(-1, 35, 100)
CS = plt.contour(X, Y, Z, levels =levels, cmap=cm.gist_stern)
plt.gca().set_xlim([-2,2])
plt.gca().set_ylim([-1,3])

#manual_locations = [(-1, -1.4), (-0.62, -0.7), (-2, 0.5), (1, 1), (2.0, 1.4), (2.4, 1.7)]
#plt.clabel(CS, inline=1, fontsize=10, manual=manual_locations)
# Out:
# (-1, 3)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, cmap=cm.gist_stern, rstride=8, cstride=8, alpha=0.2)
cset = ax.contourf(X, Y, Z, zdir='z', offset=-1, cmap=cm.gist_stern, levels =[0,0.5, 1,2,3,4,5,6,7,8,9])
cset = ax.contourf(X, Y, Z, zdir='x', offset=-3, cmap=cm.gist_stern)#, levels =[0,0.5, 1,2,3,4,5,6,7,8,9])
cset = ax.contourf(X, Y, Z, zdir='y', offset=3, cmap=cm.gist_stern)#, levels =[0,0.5, 1,2,3,4,5,6,7,8,9])

ax.set_xlabel('X')
ax.set_xlim(-3, 3)
ax.set_ylabel('Y')
ax.set_ylim(-3, 3)
ax.set_zlabel('Z')
ax.set_zlim(-1, 36)

plt.show()
